# %% [markdown]
# ### String study

# %%
x = "This is an string"
print(x)

# %%
y = """This is an multiple line string
as you can see, i can use
more than one line"""
print(y)

# %%
z = "now i'm gonna selec just an caracter"
print(z[0])

# %%
for a in "banana":
    print(a)

# %%
b = "it shows the length"
print(len(b))

# %%
c = "there are 'taurus' in this frase?"
print("taurus" in c)

# %%
if "taurus" in c :
    print("Yes, 'taurus' was wrote in c")
